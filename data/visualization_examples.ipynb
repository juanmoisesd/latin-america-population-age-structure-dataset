# %% [markdown]
# # Ejemplos de visualización del dataset demográfico

# %%
import pandas as pdimport matplotlib.pyplot as pltdf = pd.read_csv('dataset.csv')df.head()

# %% [markdown]
# ## Evolución del envejecimiento poblacional

# %%
aging = df.groupby('Año')['Pct65ms'].mean()aging.plot()plt.title('Promedio regional de población mayor de 65 años')plt.show()
